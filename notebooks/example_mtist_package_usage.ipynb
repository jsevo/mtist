# %% [markdown]
# # MTIST Code Examples

# %% [markdown]
# #### Load require packages

# %%
import os
import glob
from mtist import mtist_utils as mu
from mtist import master_dataset_generation as mdg
from mtist import assemble_mtist as am
from mtist import infer_mtist as im
from mtist import graphing_utils as gu

from matplotlib import pyplot as plt

# %config InlineBackend.figure_format='retina'
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# #### Load one single master dataset

# %%
did = 634
full_df, time, X, meta_spec = mu.load_dataset_by_did(did)
full_df
# Out:
#          time  species_0  species_1  species_2 ground_truth  timeseries_id  \
# 0    6.157576   1.366190   1.059066   0.842659    3_sp_gt_8          36656
# 1    7.369697   1.278143   1.024598   1.078108    3_sp_gt_8          36656
# 2    8.581818   0.751303   1.132562   1.218599    3_sp_gt_8          36656
# 3   10.096970   1.170699   0.949075   1.047713    3_sp_gt_8          36656
# 4   11.309091   1.177646   1.339079   1.241778    3_sp_gt_8          36656
# 5    8.581818   1.302375   0.982432   1.108768    3_sp_gt_8         416304
# 6   10.096970   0.816518   1.196774   1.296473    3_sp_gt_8         416304
# 7   11.309091   0.902028   1.111780   1.014052    3_sp_gt_8         416304
# 8   12.521212   0.970858   0.763508   0.793258    3_sp_gt_8         416304
# 9   13.733333   0.938062   0.679352   0.765672    3_sp_gt_8         416304
# 10   8.581818   0.981419   0.676823   0.741335    3_sp_gt_8        2369231
# ...

# %% [markdown]
# #### Plot one dataset

# %%
did = 634
fig, axes = gu.plot_dataset(did)

# %% [markdown]
# ## Inference (1 dataset)

# %% [markdown]
# #### run inference on one dataset

# %% [markdown]
# #### plot inference result for one dataset

# %% [markdown]
# ## Inference (all dataset)

# %% [markdown]
# #### calculate ES score for one dataset

# %% [markdown]
# ### run inference on all 1134 datasets

# %% [markdown]
# #### calculate ES score for all datasets

# %% [markdown]
# #### plot histogram for distribution of ES score

# %% [markdown]
# ## Define my inference algorithm (linear regression)

# %% [markdown]
# in the example in readme, did would be one parameter of the inferenece function
# im not sure how to incorporate did into my function.
# Could you define linear regression here to help users?

# %% [markdown]
# Grant: I don't know what you mean here
